# %%
# !pip install opencv-python --user
# Out:
# ^C
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: opencv-python in c:\users\labib\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\labib\appdata\roaming\python\python38\site-packages (from opencv-python) (1.22.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
# from matplotlib.pyplot import figure
import cv2

# %matplotlib inline

# Read in the image
img = cv2.imread('Data\images\photocasefnpvnmb33.jpg')

# Change color to RGB (from BGR)
imgC = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(imgC)

# %%
img2 = img.reshape((-1,3))

img2 = np.float32(img2)

criteria = (cv2.tre)
plt.figure(figsize=(10,10))
plt.imshow(img2)

# %%
# Use the cvtColor() function to grayscale the image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(15,20))
plt.imshow(gray_image)

# %%
# Reshaping the image into a 2D array of pixels and 3 color values (RGB)
pixel_vals = image.reshape((-1,3))

# Convert to float type
pixel_vals = np.float32(pixel_vals)

# %%
#the below line of code defines the criteria for the algorithm to stop running,
#which will happen is 100 iterations are run or the epsilon (which is the required accuracy)
#becomes 85%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
 
# then perform k-means clustering with number of clusters defined as 3
#also random centres are initially choosed for k-means clustering
k = 6
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
 
# convert data into 8-bit values
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]
 
# reshape data into the original image dimensions
segmented_image = segmented_data.reshape((image.shape))
plt.figure(figsize=(15,20))
plt.imshow(segmented_image)
